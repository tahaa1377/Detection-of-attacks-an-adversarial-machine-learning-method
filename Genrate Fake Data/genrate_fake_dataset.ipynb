# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing

# %%
fake_data = np.random.normal(0.0, 1.0, (25000,41))
fake_label_category = np.full(shape=25000,fill_value=11,dtype=int)
fake_label_label = np.full(shape=25000,fill_value=1,dtype=int)

# %%
fake_label_category.shape
# Out:
# (25000,)

# %%
fake_data.shape
# Out:
# (25000, 41)

# %%
fake_data = np.column_stack( (fake_data,fake_label_category) )
fake_data = np.column_stack( (fake_data,fake_label_label) )

# %%
fake_data.shape
# Out:
# (25000, 43)

# %%
fake_data
# Out:
# array([[-3.55368872e-01,  1.51787525e+00,  6.85896713e-01, ...,
#         -6.67881471e-01,  1.10000000e+01,  1.00000000e+00],
#        [-1.65737931e+00, -1.28970949e+00, -2.64156162e-01, ...,
#          3.42278594e-01,  1.10000000e+01,  1.00000000e+00],
#        [ 2.26352862e-01, -7.03454327e-01,  4.21406035e-01, ...,
#          7.98978355e-01,  1.10000000e+01,  1.00000000e+00],
#        ...,
#        [-1.37496041e-01, -2.09050723e-01, -2.80911531e-01, ...,
#          6.73736922e-01,  1.10000000e+01,  1.00000000e+00],
#        [ 9.49644751e-01,  1.64045888e-03, -2.40858221e-01, ...,
#         -3.51766061e-01,  1.10000000e+01,  1.00000000e+00],
#        [-2.13488554e-01, -1.02219064e+00,  1.74078147e-01, ...,
#          7.18554465e-01,  1.10000000e+01,  1.00000000e+00]])

# %%
df = pd.read_csv("/content/drive/MyDrive/datasets/UNSW-NB15/UNSW_NB15.csv")
df.drop(['id',"Unnamed: 0","service"], axis=1, inplace=True)

# %%
fake_df = pd.DataFrame(fake_data, columns = df.columns)
fake_df
# Out:
#             dur     proto     state     spkts     dpkts    sbytes    dbytes  \
# 0     -0.355369  1.517875  0.685897 -0.561398  0.805091 -0.281479  0.364885
# 1     -1.657379 -1.289709 -0.264156 -0.225763 -1.000219  0.182359 -0.791092
# 2      0.226353 -0.703454  0.421406 -0.254869  1.611123  0.678475  1.719074
# 3      0.186759 -0.099997 -0.867264 -0.222601 -1.410281 -0.060021 -0.722415
# 4     -0.485262  0.130896 -0.137213  0.385253 -0.900221  0.631268 -0.218172
# ...         ...       ...       ...       ...       ...       ...       ...
# 24995 -0.648623 -0.873705 -0.750898 -1.121411 -0.206450  0.013775  0.073414
# 24996 -0.058392 -1.005745 -0.803820  0.710921 -0.929240 -1.303112 -1.302455
# 24997 -0.137496 -0.209051 -0.280912 -0.395731  1.594723 -1.297153 -0.908863
# 24998  0.949645  0.001640 -0.240858 -0.893389  1.220731 -1.671148 -0.145090
# 24999 -0.213489 -1.022191  0.174078  0.407848  0.638431  0.188115 -0.490479
#
# ...

# %%
fake_df.to_csv('/content/drive/MyDrive/datasets/UNSW-NB15/fake_UNSW_NB15.csv',index=False)

# %%
df = pd.read_csv("/content/drive/MyDrive/datasets/UNSW-NB15/fake_UNSW_NB15.csv")
df
# Out:
#             dur     proto     state     spkts     dpkts    sbytes    dbytes  \
# 0     -0.355369  1.517875  0.685897 -0.561398  0.805091 -0.281479  0.364885
# 1     -1.657379 -1.289709 -0.264156 -0.225763 -1.000219  0.182359 -0.791092
# 2      0.226353 -0.703454  0.421406 -0.254869  1.611123  0.678475  1.719074
# 3      0.186759 -0.099997 -0.867264 -0.222601 -1.410281 -0.060021 -0.722415
# 4     -0.485262  0.130896 -0.137213  0.385253 -0.900221  0.631268 -0.218172
# ...         ...       ...       ...       ...       ...       ...       ...
# 24995 -0.648623 -0.873705 -0.750898 -1.121411 -0.206450  0.013775  0.073414
# 24996 -0.058392 -1.005745 -0.803820  0.710921 -0.929240 -1.303112 -1.302455
# 24997 -0.137496 -0.209051 -0.280912 -0.395731  1.594723 -1.297153 -0.908863
# 24998  0.949645  0.001640 -0.240858 -0.893389  1.220731 -1.671148 -0.145090
# 24999 -0.213489 -1.022191  0.174078  0.407848  0.638431  0.188115 -0.490479
#
# ...
